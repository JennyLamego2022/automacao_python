# %%
import pyautogui
import time

# pyautogui.click
# pyautogui.write
# pyautogui.press
# pyautogui.hotkey

pyautogui.PAUSE = 1

# Passo 1: Acessar o sistema da empresa
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema")
pyautogui.press("enter")

time.sleep(5)


# Passo 2: Fazer login no sistema
pyautogui.press("enter")
pyautogui.press("tab")
pyautogui.write("Meu Login")
pyautogui.press("tab")
pyautogui.write("Minha senha")
pyautogui.click(x=1981, y=523)

time.sleep(10)

# Passo 3: Baixar a base de dados
pyautogui.click(x=1724, y=344)
pyautogui.click(x=2203, y=340)
pyautogui.click(x=2295, y=774)

time.sleep(5)

pyautogui.press("enter")

# %%
# Passo 4: Calcular os indicadores
import pandas as pd

    #importar a base de dados
tabela = pd.read_csv(r"C:\Users\PC\Downloads\Compras.csv", sep = ";")
display(tabela)
    #calculo dos indicadores
        #total gasto -> somar a cluna valor final
total_gasto = tabela["ValorFinal"].sum()      

        #quantidade -> somar a coluna quantidade
quantidade = tabela["Quantidade"].sum()
        #preco medio -> total gasto / quantidade
preco_medio = total_gasto / quantidade

print(total_gasto)
print(quantidade)
print(preco_medio)
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
import pyperclip

# Passo 5: Enviar o email para a diretoria/para o chefe

# entrar no meu email
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://mail.google.com/mail")
pyautogui.press("enter")

time.sleep(5)

# clicar em escrever
pyautogui.click(x=1445, y=199)

time.sleep(10)

# preencher o email
pyautogui.write("jennylamego@hotmail.com")
pyautogui.press("tab")
time.sleep(5)
pyautogui.press("tab")

pyperclip.copy("Relatório de Compras")
pyautogui.hotkey("ctrl", "v")

pyautogui.press("tab")
time.sleep(5)

texto = f"""
Prezados,

Segue o relatório de compras:

Total gasto: R${total_gasto: ,.2f}
Quantidade de Produtos: {quantidade}
Preço médio: R${preco_medio: ,.2f}

Qualquer dúvida é só falar.

Att, 

Jennyfer Lamego
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("ctrl", "enter")

# enviar

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1843, y=659)

# %%
# !pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 59.0/59.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      -------------------------------------- 168.2/168.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...
